# %% [markdown]
# # PitchPerfectMemory
#
# - Listen to incoming audio
# - Remember the first audio signal
# - Determine the relative pitch of a second incoming signal

# %%
from IPython.display import Image
Image(filename='images/cochlea.png')

# %% [markdown]
# Source: https://mechanicalcochlea.files.wordpress.com/2011/04/cochlea.png

# %%
import numpy as np
import nengo
from tbekolay import auditory_periphery
